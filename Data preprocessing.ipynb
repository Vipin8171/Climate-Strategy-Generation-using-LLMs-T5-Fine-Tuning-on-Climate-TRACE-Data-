# %%
import pandas as pd
import numpy as np
import os

from sklearn.model_selection import train_test_split

# %%
# Path to your downloaded CSV file
csv_path = r"data/Top_Emission_Reduction_Strategies.csv"  

df = pd.read_csv(csv_path)
print("Rows:", len(df))
df.head()
# Out:
# Rows: 2463130
#    source_id                   source_name iso3_country  \
# 0  3673109.0   Sunndalsora aluminium plant          NOR
# 1  3673096.0      Fjardaal aluminium plant          ISL
# 2  3673097.0  Grundartangi aluminium plant          ISL
# 3  3673113.0        Karmoy aluminium plant          NOR
# 4  3673098.0    Straumsvik aluminium plant          ISL
#
#   original_inventory_sector  strategy_id                    strategy_name  \
# 0                  aluminum       155353  Recycled feedstock for smelting
# 1                  aluminum       155353  Recycled feedstock for smelting
# 2                  aluminum       155353  Recycled feedstock for smelting
# 3                  aluminum       155353  Recycled feedstock for smelting
# 4                  aluminum       155353  Recycled feedstock for smelting
#
#    total_emissions_reduced_per_year         gas  \
# 0                     779690.045836  co2e_100yr
# 1                     757801.521906  co2e_100yr
# 2                     690873.182364  co2e_100yr
# 3                     526290.780939  co2e_100yr
# 4                     431795.738978  co2e_100yr
#
#                                 strategy_description  difficulty_score
# 0  Use recycled aluminum as an input to reduce th...          1.000000
# 1  Use recycled aluminum as an input to reduce th...          1.000002
# 2  Use recycled aluminum as an input to reduce th...          1.000007
# 3  Use recycled aluminum as an input to reduce th...          1.000024
# 4  Use recycled aluminum as an input to reduce th...          1.000039

# %%
print(df.columns.tolist())
# Out:
# ['source_id', 'source_name', 'iso3_country', 'original_inventory_sector', 'strategy_id', 'strategy_name', 'total_emissions_reduced_per_year', 'gas', 'strategy_description', 'difficulty_score']

# %%
# Keep only necessary columns
df = df[[
    "source_name",
    "iso3_country",
    "original_inventory_sector",
    "total_emissions_reduced_per_year",
    "difficulty_score",
    "strategy_description"
]]

# Drop missing strategies
df = df.dropna(subset=["strategy_description"])

# Remove duplicates
df = df.drop_duplicates(subset=["source_name", "strategy_description"])

print("After cleaning:", len(df))
df.head()
# Out:
# After cleaning: 1419567
#                     source_name iso3_country original_inventory_sector  \
# 0   Sunndalsora aluminium plant          NOR                  aluminum
# 1      Fjardaal aluminium plant          ISL                  aluminum
# 2  Grundartangi aluminium plant          ISL                  aluminum
# 3        Karmoy aluminium plant          NOR                  aluminum
# 4    Straumsvik aluminium plant          ISL                  aluminum
#
#    total_emissions_reduced_per_year  difficulty_score  \
# 0                     779690.045836          1.000000
# 1                     757801.521906          1.000002
# 2                     690873.182364          1.000007
# 3                     526290.780939          1.000024
# 4                     431795.738978          1.000039
#
#                                 strategy_description
# 0  Use recycled aluminum as an input to reduce th...
# 1  Use recycled aluminum as an input to reduce th...
# 2  Use recycled aluminum as an input to reduce th...
# 3  Use recycled aluminum as an input to reduce th...
# 4  Use recycled aluminum as an input to reduce th...

# %%
# Convert emission reduction from CO2-eq to million tons (Mt)
df["reduction_Mt"] = df["total_emissions_reduced_per_year"] / 1e6

# Map difficulty to qualitative levels (optional)
df["difficulty_level"] = df["difficulty_score"].apply(
    lambda x: "Short-term" if x <= 1.5 else ("Mid-term" if x <= 3 else "Long-term")
)

df.head()
# Out:
#                     source_name iso3_country original_inventory_sector  \
# 0   Sunndalsora aluminium plant          NOR                  aluminum
# 1      Fjardaal aluminium plant          ISL                  aluminum
# 2  Grundartangi aluminium plant          ISL                  aluminum
# 3        Karmoy aluminium plant          NOR                  aluminum
# 4    Straumsvik aluminium plant          ISL                  aluminum
#
#    total_emissions_reduced_per_year  difficulty_score  \
# 0                     779690.045836          1.000000
# 1                     757801.521906          1.000002
# 2                     690873.182364          1.000007
# 3                     526290.780939          1.000024
# 4                     431795.738978          1.000039
#
#                                 strategy_description  reduction_Mt  \
# 0  Use recycled aluminum as an input to reduce th...      0.779690
# 1  Use recycled aluminum as an input to reduce th...      0.757802
# 2  Use recycled aluminum as an input to reduce th...      0.690873
# 3  Use recycled aluminum as an input to reduce th...      0.526291
# 4  Use recycled aluminum as an input to reduce th...      0.431796
#
#   difficulty_level
# 0       Short-term
# 1       Short-term
# 2       Short-term
# 3       Short-term
# 4       Short-term

# %%
def build_input(row):
    return (
        f"Facility: {row['source_name']} | "
        f"Country: {row['iso3_country']} | "
        f"Sector: {row['original_inventory_sector']} | "
        f"EmissionReductionPotential(Mt): {row['reduction_Mt']:.3f} | "
        f"Difficulty: {row['difficulty_level']}"
    )

def build_output(row):
    return row["strategy_description"].strip()

df["input"] = df.apply(build_input, axis=1)
df["output"] = df.apply(build_output, axis=1)

df[["input", "output"]].head()
# Out:
#                                                input  \
# 0  Facility: Sunndalsora aluminium plant | Countr...
# 1  Facility: Fjardaal aluminium plant | Country: ...
# 2  Facility: Grundartangi aluminium plant | Count...
# 3  Facility: Karmoy aluminium plant | Country: NO...
# 4  Facility: Straumsvik aluminium plant | Country...
#
#                                               output
# 0  Use recycled aluminum as an input to reduce th...
# 1  Use recycled aluminum as an input to reduce th...
# 2  Use recycled aluminum as an input to reduce th...
# 3  Use recycled aluminum as an input to reduce th...
# 4  Use recycled aluminum as an input to reduce th...

# %%
N = 50000   # choose 1500, 3000, 5000 etc.
df_small = df.sample(n=N, random_state=42)

print("Sampled rows:", len(df_small))
df_small.head()
# Out:
# Sampled rows: 50000
#                                  source_name iso3_country  \
# 134012           DEU_MatureDairyCattle_24658          DEU
# 1606317                      Abramut Commune          ROU
# 567798   USA_Wisconsin_OtherBeefCattle_22623          USA
# 482021                   Pampán Municipality          VEN
# 734982                    Kasrouane District          LBN
#
#                      original_inventory_sector  \
# 134012   enteric-fermentation-cattle-operation
# 1606317                       other-energy-use
# 567798      manure-management-cattle-operation
# 482021                 manure-applied-to-soils
# 734982                          cropland-fires
#
#          total_emissions_reduced_per_year  difficulty_score  \
# 134012                          30.802547          3.377383
# 1606317                        158.824044         10.000000
# 567798                          11.671609          4.841614
# 482021                        3531.927593          4.431047
# 734982                         322.668169          5.410377
#
#                                       strategy_description  reduction_Mt  \
# 134012   Feed additives have been found to deliver 20% ...      0.000031
# 1606317  Reduce emissions by factor of 0.1 via unspecif...      0.000159
# 567798   For non-dairy cattle high productivity, change...      0.000012
# 482021   Injecting or incorporating manure slurry below...      0.003532
# 734982   This practice involves the removal of crop res...      0.000323
#
#         difficulty_level                                              input  \
# 134012         Long-term  Facility: DEU_MatureDairyCattle_24658 | Countr...
# 1606317        Long-term  Facility: Abramut Commune | Country: ROU | Sec...
# 567798         Long-term  Facility: USA_Wisconsin_OtherBeefCattle_22623 ...
# 482021         Long-term  Facility: Pampán Municipality | Country: VEN |...
# 734982         Long-term  Facility: Kasrouane District | Country: LBN | ...
#
#                                                     output
# 134012   Feed additives have been found to deliver 20% ...
# 1606317  Reduce emissions by factor of 0.1 via unspecif...
# 567798   For non-dairy cattle high productivity, change...
# 482021   Injecting or incorporating manure slurry below...
# 734982   This practice involves the removal of crop res...

# %%
train_df, test_df = train_test_split(df_small, test_size=0.20, random_state=42)
val_df, test_df = train_test_split(test_df, test_size=0.50, random_state=42)

print(len(train_df), len(val_df), len(test_df))
# Out:
# 40000 5000 5000

# %%
os.makedirs("processed_data_50k", exist_ok=True)

train_df[["input","output"]].to_csv("processed_data_50k/train.csv", index=False)
val_df[["input","output"]].to_csv("processed_data_50k/val.csv", index=False)
test_df[["input","output"]].to_csv("processed_data_50k/test.csv", index=False)

print("Saved processed dataset!")
# Out:
# Saved processed dataset!
